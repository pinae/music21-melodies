# %% [markdown]
# ## Rythm
#
# For simplicity the rhythms also use te standard piano (G in 4th octave). Percussio instruments are available via Midi track 10 but that needs additional configuration. Our recommendation is to export to MuseScore and arrange drums there.

# %%
from music21 import *
from random import choice

# %% [markdown]
# The idea of this algorithm is that long notes can be separated into two notes of half the length or two notes of the same length could be merged to one longer note. Each of these operations feels like a minor modification of a previous rythm. That makes sure that some degree of predictability is preserved.

# %%
def modify_rhythm(melody: stream.Stream):
    def list_available_merges():
        available_merges = []
        for pos, (n1, n2) in enumerate(zip(melody.notes[:-1], melody.notes[1:])):
            if n1.duration == n2.duration:
                available_merges.append(pos)
        return available_merges
    def list_available_splits():
        return [i for i, n in enumerate(melody.notes) if n.duration.quarterLength >= 0.5]
    available_merges = list_available_merges()
    available_splits = list_available_splits()
    print(f"There are these {available_merges} merges and these {available_splits} splits available.")
    def do_random_merge():
        pos = choice(available_merges)
        print(f"Merging at {pos}.")
        new_melody = stream.Stream()
        for i, tone in enumerate(melody):
            tql = tone.duration.quarterLength
            if i != pos + 1:
                new_melody.append(note.Note(
                    pitch = tone.pitch, 
                    quarterLength = tql * 2 if i == pos else tql))
        return new_melody
    def do_random_split():
        pos = choice(available_splits)
        print(f"Splitting at {pos}.")
        new_melody = stream.Stream()
        for i, tone in enumerate(melody):
            tql = tone.duration.quarterLength
            if i == pos:
                tql = 0.5 * tql
                new_melody.append(note.Note(
                    pitch = tone.pitch, 
                    quarterLength = tql))
            new_melody.append(note.Note(
                pitch = tone.pitch,
                quarterLength = tql))
        return new_melody
    if len(available_merges) >= 1 and len(available_splits) >= 1:
        return choice((do_random_merge, do_random_split))()
    elif len(available_merges) >= 1:
        return do_random_merge()
    else:
        return do_random_split()

# %%
part = stream.Part()
s = stream.Stream([note.Note('G4', quarterLength=2), 
                   note.Note('G4', quarterLength=0.5), 
                   note.Note('G4', quarterLength=0.5),
                   note.Note('G4', quarterLength=1)])
part.append(s)
part.append(s.transpose(0))
for _ in range(16):
    s = modify_rhythm(s)
    part.append(s)
    part.append(s.transpose(0))
part.show()
part.show('midi')
# Out:
# There are these [1] merges and these [0, 1, 2, 3] splits available.
# Merging at 1.
# There are these [1] merges and these [0, 1, 2] splits available.
# Splitting at 2.
# There are these [2] merges and these [0, 1, 2, 3] splits available.
# Splitting at 3.
# There are these [3] merges and these [0, 1, 2] splits available.
# Splitting at 0.
# There are these [0, 1, 4] merges and these [0, 1, 2, 3] splits available.
# Merging at 0.
# There are these [3] merges and these [0, 1, 2] splits available.
# Merging at 3.
# There are these [2] merges and these [0, 1, 2, 3] splits available.
# Splitting at 2.
# There are these [2] merges and these [0, 1, 4] splits available.
# Splitting at 0.
# There are these [0, 1, 3] merges and these [0, 1, 2, 5] splits available.
# Merging at 1.
# There are these [2] merges and these [0, 1, 4] splits available.
# Merging at 2.
# There are these [2] merges and these [0, 1, 2, 3] splits available.
# Splitting at 1.
# There are these [0, 1, 3] merges and these [0, 1, 2, 3, 4] splits available.
# Splitting at 1.
# There are these [1, 4] merges and these [0, 1, 2, 3, 4, 5] splits available.
# Merging at 4.
# There are these [1, 3] merges and these [0, 1, 2, 3, 4] splits available.
# Merging at 1.
# There are these [0, 1, 2] merges and these [0, 1, 2, 3] splits available.
# Splitting at 3.
# There are these [0, 1, 3] merges and these [0, 1, 2, 3, 4] splits available.
# Splitting at 1.
#                 <div id='midiPlayerDiv4809'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4809');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
percussion = instrument.BassDrum()
part.insert(0, percussion)
print(part.flat.notes[0].pitch.midi)
part.show('midi')
part.write('midi', 'rhythm.mid')
# Out:
# 67
#                 <div id='midiPlayerDiv5876'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv5876');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# 'rhythm.mid'

# %%
x = converter.parse('rhythm.mid')

# %%
for n in x.flat.notes:
    print(n)
print(type(x.flat))
for i in x.flat.getInstruments():
  print(repr(i))
# Out:
# <music21.note.Unpitched object at 0x7fb09e287760>
# <music21.note.Unpitched object at 0x7fb09e286e30>
# <music21.note.Unpitched object at 0x7fb09e2879d0>
# <music21.note.Unpitched object at 0x7fb09e287730>
# <music21.note.Unpitched object at 0x7fb09e287250>
# <music21.note.Unpitched object at 0x7fb09e286fe0>
# <music21.note.Unpitched object at 0x7fb09e286d40>
# <music21.note.Unpitched object at 0x7fb09e286b90>
# <music21.note.Unpitched object at 0x7fb09e2868c0>
# <music21.note.Unpitched object at 0x7fb09e286230>
# <music21.note.Unpitched object at 0x7fb09e287fd0>
# <music21.note.Unpitched object at 0x7fb09e287520>
# <music21.note.Unpitched object at 0x7fb09e286b30>
# <music21.note.Unpitched object at 0x7fb09e2c0d90>
# <music21.note.Unpitched object at 0x7fb09e2c09a0>
# <music21.note.Unpitched object at 0x7fb09e2c1f00>
# <music21.note.Unpitched object at 0x7fb09e2c0640>
# <music21.note.Unpitched object at 0x7fb09e2c0a30>
# <music21.note.Unpitched object at 0x7fb09e2c1db0>
# <music21.note.Unpitched object at 0x7fb09e2c0c40>
# <music21.note.Unpitched object at 0x7fb09e2c0520>
# <music21.note.Unpitched object at 0x7fb09e2c07c0>
# <music21.note.Unpitched object at 0x7fb09e2c0bb0>
# <music21.note.Unpitched object at 0x7fb09e2c1ff0>
# <music21.note.Unpitched object at 0x7fb09e2c1c00>
# <music21.note.Unpitched object at 0x7fb09e2c1f60>
# <music21.note.Unpitched object at 0x7fb09e2c1d80>
# <music21.note.Unpitched object at 0x7fb09e2c0970>
# <music21.note.Unpitched object at 0x7fb09e2c0d60>
# <music21.note.Unpitched object at 0x7fb09e2c18d0>
# <music21.note.Unpitched object at 0x7fb09e2c2170>
# <music21.note.Unpitched object at 0x7fb09e2c2560>
# <music21.note.Unpitched object at 0x7fb09e2c0eb0>
# <music21.note.Unpitched object at 0x7fb09e2c1090>
# <music21.note.Unpitched object at 0x7fb09e2c0910>
# <music21.note.Unpitched object at 0x7fb09e2c1390>
# <music21.note.Unpitched object at 0x7fb09e2c1180>
# <music21.note.Unpitched object at 0x7fb09e2c0b50>
# <music21.note.Unpitched object at 0x7fb09e2c1300>
# <music21.note.Unpitched object at 0x7fb09e2c0c10>
# <music21.note.Unpitched object at 0x7fb09e2c0880>
# <music21.note.Unpitched object at 0x7fb09e2c0940>
# <music21.note.Unpitched object at 0x7fb09e2c11b0>
# <music21.note.Unpitched object at 0x7fb09e2c0ee0>
# <music21.note.Unpitched object at 0x7fb09e2c0fd0>
# <music21.note.Unpitched object at 0x7fb09e2c0c70>
# <music21.note.Unpitched object at 0x7fb09e2c18a0>
# <music21.note.Unpitched object at 0x7fb09e2c1a50>
# <music21.note.Unpitched object at 0x7fb09e2c1b40>
# <music21.note.Unpitched object at 0x7fb09e2c1d50>
# <music21.note.Unpitched object at 0x7fb09e2c24a0>
# <music21.note.Unpitched object at 0x7fb09e2c2260>
# <music21.note.Unpitched object at 0x7fb09e2c2020>
# <music21.note.Unpitched object at 0x7fb09e2c0460>
# <music21.note.Unpitched object at 0x7fb09e2c23e0>
# <music21.note.Unpitched object at 0x7fb09e2c2140>
# <music21.note.Unpitched object at 0x7fb09e2c21a0>
# <music21.note.Unpitched object at 0x7fb09e21b9d0>
# <music21.note.Unpitched object at 0x7fb09e21b790>
# <music21.note.Unpitched object at 0x7fb09e21bf70>
# <music21.note.Unpitched object at 0x7fb09e21b910>
# <music21.note.Unpitched object at 0x7fb09e21b280>
# <music21.note.Unpitched object at 0x7fb09e21abc0>
# <music21.note.Unpitched object at 0x7fb09e21baf0>
# <music21.note.Unpitched object at 0x7fb09e21b0d0>
# <music21.note.Unpitched object at 0x7fb09e21ba60>
# <music21.note.Unpitched object at 0x7fb09e21b670>
# <music21.note.Unpitched object at 0x7fb09e21bdc0>
# <music21.note.Unpitched object at 0x7fb09e21b700>
# <music21.note.Unpitched object at 0x7fb09e21bbb0>
# <music21.note.Unpitched object at 0x7fb09e21bca0>
# <music21.note.Unpitched object at 0x7fb09e21b970>
# <music21.note.Unpitched object at 0x7fb09e390880>
# <music21.note.Unpitched object at 0x7fb09e3935e0>
# <music21.note.Unpitched object at 0x7fb09e392fb0>
# <music21.note.Unpitched object at 0x7fb09e390340>
# <music21.note.Unpitched object at 0x7fb09e390a00>
# <music21.note.Unpitched object at 0x7fb09e391de0>
# <music21.note.Unpitched object at 0x7fb09e393220>
# <music21.note.Unpitched object at 0x7fb09e392f20>
# <music21.note.Unpitched object at 0x7fb09e391cc0>
# <music21.note.Unpitched object at 0x7fb09e390280>
# <music21.note.Unpitched object at 0x7fb09e3922f0>
# <music21.note.Unpitched object at 0x7fb09e392590>
# <music21.note.Unpitched object at 0x7fb09e3929e0>
# <music21.note.Unpitched object at 0x7fb09e393460>
# <music21.note.Unpitched object at 0x7fb09e393730>
# <music21.note.Unpitched object at 0x7fb09e393fa0>
# <music21.note.Unpitched object at 0x7fb09e3910c0>
# <music21.note.Unpitched object at 0x7fb09e390910>
# <music21.note.Unpitched object at 0x7fb09e3928f0>
# <music21.note.Unpitched object at 0x7fb09e390d00>
# <music21.note.Unpitched object at 0x7fb09e3906a0>
# <music21.note.Unpitched object at 0x7fb09e390a60>
# <music21.note.Unpitched object at 0x7fb09e3915a0>
# <music21.note.Unpitched object at 0x7fb09e390820>
# <music21.note.Unpitched object at 0x7fb09e3906d0>
# <music21.note.Unpitched object at 0x7fb09e390640>
# <music21.note.Unpitched object at 0x7fb09e3918a0>
# <music21.note.Unpitched object at 0x7fb09e3901c0>
# <music21.note.Unpitched object at 0x7fb09e390eb0>
# <music21.note.Unpitched object at 0x7fb09e393eb0>
# <music21.note.Unpitched object at 0x7fb09e393d30>
# <music21.note.Unpitched object at 0x7fb09e393d60>
# <music21.note.Unpitched object at 0x7fb09e393a00>
# <music21.note.Unpitched object at 0x7fb09e3937f0>
# <music21.note.Unpitched object at 0x7fb09e393850>
# <music21.note.Unpitched object at 0x7fb09e392cb0>
# <music21.note.Unpitched object at 0x7fb09e393a60>
# <music21.note.Unpitched object at 0x7fb09e392e60>
# <music21.note.Unpitched object at 0x7fb09e392e30>
# <music21.note.Unpitched object at 0x7fb09e3933a0>
# <music21.note.Unpitched object at 0x7fb09e392a40>
# <music21.note.Unpitched object at 0x7fb09e392650>
# <music21.note.Unpitched object at 0x7fb09e392f80>
# <music21.note.Unpitched object at 0x7fb09e392b60>
# <music21.note.Unpitched object at 0x7fb09e392f50>
# <music21.note.Unpitched object at 0x7fb09e392320>
# <music21.note.Unpitched object at 0x7fb09e391f00>
# <music21.note.Unpitched object at 0x7fb09e391c90>
# <music21.note.Unpitched object at 0x7fb09e391d20>
# <music21.note.Unpitched object at 0x7fb09e391b70>
# <music21.note.Unpitched object at 0x7fb09e2fa4a0>
# <music21.note.Unpitched object at 0x7fb09e2fa530>
# <music21.note.Unpitched object at 0x7fb09e2fa5f0>
# <music21.note.Unpitched object at 0x7fb09e2fa350>
# <music21.note.Unpitched object at 0x7fb09e2fa140>
# <music21.note.Unpitched object at 0x7fb09e2f9f90>
# <music21.note.Unpitched object at 0x7fb09e2fa3b0>
# <music21.note.Unpitched object at 0x7fb09e2fa1d0>
# <music21.note.Unpitched object at 0x7fb09e2fa410>
# <music21.note.Unpitched object at 0x7fb09e2fa1a0>
# <music21.note.Unpitched object at 0x7fb09e2fa290>
# <music21.note.Unpitched object at 0x7fb09e2fa320>
# <music21.note.Unpitched object at 0x7fb09e2fa200>
# <music21.note.Unpitched object at 0x7fb09e2f9ff0>
# <music21.note.Unpitched object at 0x7fb09e2fa080>
# <music21.note.Unpitched object at 0x7fb09e2fa110>
# <music21.note.Unpitched object at 0x7fb09e2fa680>
# <music21.note.Unpitched object at 0x7fb09e2fa6e0>
# <music21.note.Unpitched object at 0x7fb09e2fa740>
# <music21.note.Unpitched object at 0x7fb09e2fa7a0>
# <music21.note.Unpitched object at 0x7fb09e2fa830>
# <music21.note.Unpitched object at 0x7fb09e2fa890>
# <music21.note.Unpitched object at 0x7fb09e2fa8f0>
# <music21.note.Unpitched object at 0x7fb09e2fa950>
# <music21.note.Unpitched object at 0x7fb09e2fa9b0>
# <music21.note.Unpitched object at 0x7fb09e2faa40>
# <music21.note.Unpitched object at 0x7fb09e2faaa0>
# <music21.note.Unpitched object at 0x7fb09e2fab00>
# <music21.note.Unpitched object at 0x7fb09e2fab60>
# <music21.note.Unpitched object at 0x7fb09e2fabc0>
# <music21.note.Unpitched object at 0x7fb09e2fac50>
# <music21.note.Unpitched object at 0x7fb09e2facb0>
# <music21.note.Unpitched object at 0x7fb09e2fad10>
# <music21.note.Unpitched object at 0x7fb09e2fad70>
# <music21.note.Unpitched object at 0x7fb09e2fadd0>
# <music21.note.Unpitched object at 0x7fb09e2fae30>
# <music21.note.Unpitched object at 0x7fb09e2faec0>
# <music21.note.Unpitched object at 0x7fb09e2faf20>
# <music21.note.Unpitched object at 0x7fb09e2faf80>
# <music21.note.Unpitched object at 0x7fb09e2fafe0>
# <music21.note.Unpitched object at 0x7fb09e2fb040>
# <music21.note.Unpitched object at 0x7fb09e2fb0a0>
# <class 'music21.stream.base.Score'>
# <music21.instrument.BassDrum 'Bass Drum: Bass Drum'>
# <music21.instrument.UnpitchedPercussion 'Percussion'>
